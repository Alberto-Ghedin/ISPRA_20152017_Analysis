# %%
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, to_tree, ClusterNode
from sklearn.cluster import AgglomerativeClustering
_HOME_ = "/mnt/d"
import plotting
import os

# %%
X = np.array([[1, 0, 0], [0, 0, 1], [0, 1, 0],
              [1, 1, 0]])
clustering = AgglomerativeClustering(distance_threshold=0, n_clusters=None).fit(X)
clustering.labels_
# Out:
# array([3, 1, 2, 0])

# %%
plotting.plot_dendrogram(clustering)
