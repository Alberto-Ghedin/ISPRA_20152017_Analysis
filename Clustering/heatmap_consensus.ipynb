# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.listdir("./Results/Spectral_varying_sigma/2024_04_24/11_06_40")
# Out:
# ['clust_consensus_spectral_sigma_3_20.csv', 'descr.txt']

# %%
consensus = pd.read_csv("./Results/Spectral_varying_sigma/2024_04_24/11_06_40/clust_consensus_spectral_sigma_3_20.csv")

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ari_cons = consensus.filter(like='ARI')
ari_cons.columns = ari_cons.loc[0,:]
ari_cons = ari_cons.loc[1:, :].astype(float)
sns.heatmap(
data = ari_cons, 
ax = ax
)
# Out:
# <Axes: xlabel='0'>
